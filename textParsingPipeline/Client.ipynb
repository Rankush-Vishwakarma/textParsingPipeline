# %%
import requests

ENDPOINT_URL = "https://pork-bracket-madness-digital.trycloudflare.com/upload-url"

data = {"url": "https://www.geeksforgeeks.org/python/convert-mp3-to-wav-using-python/"}

response = requests.post(ENDPOINT_URL, data=data)

print(response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"output_path":"output/4eea8d209342959467afea0ad9d1905203208d5a6da477567abf408c4d3b6a29.json","sample":"Convert mp3 to wav using Python - GeeksforGeeks Skip to content Tutorials Data Structures & Algorithms ML & Data Science Interview Corner Programming Languages Web Development CS Subjects DevOps And L"}'

# %%
import io
# !curl -F "file=@/content/Developer_Test_Task_-_Text_Parsing_Pipeline.pdf" https://pork-bracket-madness-digital.trycloudflare.com/upload/
# Out:
# {"output_path":"output/4b67415f16ea94bab382553d1732ef1d447abf547b8188fbca38bb82bdfc3f8a.json","sample":"Test Task: Text Parsing Pipeline\nBackground & Objective\nYour task is to design and implement a scalable, cost-efficient, and high-quality document-\ningestion pipeline on GCP or AWS. This pipeline will"}

# %%
import io
# !curl -F "file=@/content/file_example_XLS_10.xlsx" https://pork-bracket-madness-digital.trycloudflare.com/upload/
# Out:
# {"detail":"Sheet name is an empty list"}

# %%
import io
# !curl -F "file=@/content/example-good.xlsx" https://pork-bracket-madness-digital.trycloudflare.com/upload/
# Out:
# {"output_path":"output/1ce2dc269c1830e7271e1dce61c26a068db7d3329b1a02dde5ba9c314c8552a4.json","sample":"    City      State\nNew York   New York\n Seattle Washington"}

# %%
# !curl -X POST https://departure-performance-summit-inspector.trycloudflare.com/upload-multiple/ \
  -F "files=@/content/example-good.xlsx" \
  -F "files=@/content/example-good - 1.xlsx" \
  -F "files=@/content/example-good - 2.xlsx"
# Out:
# {"files":[{"filename":"example-good.xlsx","output_path":"output/1ce2dc269c1830e7271e1dce61c26a068db7d3329b1a02dde5ba9c314c8552a4.json","sample":"    City      State\nNew York   New York\n Seattle Washington"},{"filename":"example-good - 1.xlsx","output_path":"output/f0f51446e3e9f81343391c90921dbe7968e0922dd66116770cbeeba9b80778d1.json","sample":"    City      State\nNew York   New York\n Seattle Washington\nNew York   New York\n Seattle Washington"},{"filename":"example-good - 2.xlsx","output_path":"output/578db24878243d61abeef0816d42f65e06c0ca235b4b56ddbcb0c198f072fba2.json","sample":"    City      State\nNew York   New York\n Seattle Washington\nNew York   New York"}]}
